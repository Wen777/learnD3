# %% [markdown]
# #Data visualization and D3.js
#
# ####Data visualization is a part of data science. This course is teaching data visualization by d3.js.
#
# #####Reference
# #####https://www.udacity.com/course/ud507

# %% [markdown]
# #Lesson one
#
# ##Good data visualization
#
# #####Reference:
#
# * ***http://www.smallmeans.com/new-york-times-infographics/***
# * ***http://infosthetics.com/***
# * ***http://flowingdata.com/***
#
# ##Visual Encoding:
#
# ###Map data in display element
#
# ####If there are three variables in data. How to display data ?
#
# ***"however 3d models are poorly perceived by rice as it's more difficult to make quantative comparison between points"***
#
# ***"we can use Retinal Variable to encode aditional variables"***
#
# ####Retinal Variable:
#
# *Color hue, texture, and shape are great for encoding nominal variables.*
#
# |                |              |
# |----------------|--------------|
# |color saturation| **color hue**|
# |  Orientation   |  **texture** |
# |       size     |   **Shape**  |
#
# ********
# ####Global trends: Wealth & Health of Nations
# ![Wealth & Health of Nations](http://charliepark.org/images/slopegraphs/natgeo_scatter.jpg "Wealth & Health of Nations")
#
# |        Data          |    Display   |
# |----------------------|--------------|
# |  life expectancy     |  position y  |
# | spending per person  |  position x  |
# |    total population  |     size     |
# |  geographical region |    color     |
# |          time        |    animation |
#
# #####Reference:
# #####http://www.gapminder.org/world/
# ***
# ###Practice: Visual Encoding
#
# ![World Cup all-time top socrers](http://blog.thomsonreuters.com/wp-content/uploads/2014/06/scorers-1024x824.jpg "World Cup all-time top socrers")
#
# ***
# ###Win, Lose or Draw
#
# ![Win, Lose or Draw](http://blog.thomsonreuters.com/wp-content/uploads/2014/07/semis-600x1024.jpg "Win, Lose or Draw")
#
# ***Small multiple***
# https://en.wikipedia.org/wiki/Small_multiple
# *****
# ###Rankings of Visual Encodings
#
# ####Position -> length -> angle / slope -> Area -> Volume -> Color / Density
#
# ####More Accurate -------------------------------------------> Less Accurate
#
# *****
# ###Decomposing Visualizations
# ***http://www.targetprocess.com/articles/visual-encoding.html***
# *****
# ##Question:
# ###Q 1. Identifying data types, why "docto vists per year" is "Ordered" type ?
# ###A 1. "We've taken quantative data to split it up into dense which makes this data type into ordered datat type."
